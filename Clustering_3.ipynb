# %% [markdown]
# <a href="https://colab.research.google.com/github/FahmidaNourin/CSE445_Machine_Learning/blob/main/Clustering_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from sklearn.cluster import KMeans
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib import style
style.use("ggplot")
# %matplotlib inline

# %%
import random

data_table={
    "x": random.sample(range(1, 150), 40),
    "y": random.sample(range(1, 150), 40)
}

data=pd.DataFrame(data_table)



plt.scatter(
   data["x"], data['y'],
   c='white', marker='o',
   edgecolor='red', s=30
)
plt.show()

# %%
data.head()
# Out:
#      x    y
# 0   97  124
# 1  103  137
# 2    3   47
# 3  119    6
# 4   15   59

# %%
num_of_cluster = 4
kmeans = KMeans(n_clusters=num_of_cluster)
kmeans.fit(data)

centroids = kmeans.cluster_centers_
labels = kmeans.labels_

print(centroids)
print(labels)
# Out:
# [[106.          41.57142857]
#  [114.         117.72727273]
#  [ 40.83333333 132.66666667]
#  [ 36.55555556  48.55555556]]
# [1 1 3 0 3 0 2 2 1 1 3 0 1 2 0 0 3 3 2 1 3 1 0 1 3 0 1 3 3 1 2 0 0 1 2 0 0
#  0 0 0]
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(

# %%
data['labels'] = labels
data
# Out:
#       x    y  labels
# 0    97  124       1
# 1   103  137       1
# 2     3   47       3
# 3   119    6       0
# 4    15   59       3
# 5    82   32       0
# 6    39  125       2
# 7    20  145       2
# 8   140  107       1
# 9    98  148       1
# 10   58   37       3
# 11   89   52       0
# 12  126  104       1
# 13   23  140       2
# 14  139   67       0
# 15   79   18       0
# 16   33   16       3
# 17   52   49       3
# 18   68  146       2
# 19   96  110       1
# 20   36    8       3
# 21  112  123       1
# 22  115   31       0
# 23  145   92       1
# 24   71   73       3
# 25  104   77       0
# 26  127   93       1
# 27   43   61       3
# 28   18   87       3
# 29   93  143       1
# 30   65  111       2
# 31   83   17       0
# 32  109   46       0
# 33  117  114       1
# 34   30  129       2
# 35   91   43       0
# 36  110   69       0
# 37  107   36       0
# 38  125   50       0
# 39  132   38       0

# %%
data['labels'] = labels




import random
get_colors = lambda n: ["#%06x" % random.randint(0, 0xFFFFFF) for _ in range(n)]
get_colors(num_of_cluster)





initial_group = data[data['labels']==0].plot( kind='scatter', x='x', y='y', color='DarkGreen', label="Cluster 1" )

for i in range(1,num_of_cluster):
   data[data['labels']==i].plot( kind='scatter', x='x', y='y', color=get_colors(num_of_cluster)[i], ax=initial_group, label="Cluster "+str(i+1) )







initial_group.legend(loc='upper center', bbox_to_anchor=(0.5, 1.05),
          ncol=3, fancybox=True, shadow=True)


plt.scatter(centroids[:, 0],centroids[:, 1], marker = "*",s=150, linewidths = 2, zorder = 10)

plt.show()
