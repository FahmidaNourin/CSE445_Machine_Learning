# %% [markdown]
# <a href="https://colab.research.google.com/github/FahmidaNourin/CSE445_Machine_Learning/blob/main/clustering_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
A1(2, 10), A2(2, 5), A3(8, 4), A4(5, 8), A5(7, 5), A6(6, 4), A7(1, 2), A8(4, 9)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-10-bb20a544d453> in <cell line: 1>()
# ----> 1 A1(2, 10), A2(2, 5), A3(8, 4), A4(5, 8), A5(7, 5), A6(6, 4), A7(1, 2), A8(4, 9)
#
# NameError: name 'A1' is not defined

# %%
from sklearn.cluster import KMeans
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib import style
style.use("ggplot")
# %matplotlib inline

# %%
data_table={
    "x":[2,2,8,5,7,6,1,4],
    "y":[10,5,4,8,5,4,2,9]
}

data=pd.DataFrame(data_table)

# %%
data.head(data.shape[0])
# Out:
#    x   y
# 0  2  10
# 1  2   5
# 2  8   4
# 3  5   8
# 4  7   5
# 5  6   4
# 6  1   2
# 7  4   9

# %%
kmeans = KMeans(n_clusters=3)
kmeans.fit(data)

centroids = kmeans.cluster_centers_
labels = kmeans.labels_

print(centroids)
print(labels)
# Out:
# [[7.         4.33333333]
#  [1.5        3.5       ]
#  [3.66666667 9.        ]]
# [2 1 0 2 0 0 1 2]
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(

# %%
data['labels'] = labels
data
# Out:
#    x   y  labels
# 0  2  10       2
# 1  2   5       1
# 2  8   4       0
# 3  5   8       2
# 4  7   5       0
# 5  6   4       0
# 6  1   2       1
# 7  4   9       2

# %%
data['labels'] = labels

#plt.plot(data, colors[data['labels'], markersize = 10)

group1 = data[data['labels']==0].plot( kind='scatter', x='x', y='y', color='DarkGreen', label="Group 1" )
group2 = data[data['labels']==1].plot( kind='scatter', x='x', y='y', color='Brown', ax=group1, label="Group 2" )
group3 = data[data['labels']==2].plot( kind='scatter', x='x', y='y', color='Blue', ax=group1, label="Group 3" )






group1.legend(loc='upper center', bbox_to_anchor=(0.5, 1.05),
          ncol=3, fancybox=True, shadow=True)


plt.scatter(centroids[:, 0],centroids[:, 1], marker = "x", s=150, linewidths = 5, zorder = 10)

plt.show()
